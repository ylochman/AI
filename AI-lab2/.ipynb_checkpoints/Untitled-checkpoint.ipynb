# %%
import numpy as np
import pandas as pd
import scipy

# %%
cities = pd.read_csv('Cities.txt', sep=',')
distances = pd.read_csv('Distances.txt', sep=',')
distances
# Out:
#              Місто1           Місто2  Відстань_км
# 0           Вільнюс            Брест          531
# 1          Вітебськ            Брест          638
# 2          Вітебськ          Вільнюс          360
# 3           Вороніж         Вітебськ          869
# 4           Вороніж        Волгоград          581
# 5         Волгоград         Вітебськ         1455
# 6          Вітебськ  Нижній Новгород          911
# 7           Вільнюс       Даугавпілс          211
# 8       Калінінград            Брест          699
# 9       Калінінград          Вільнюс          333
# 10           Каунас          Вільнюс          102
# 11             Київ          Вільнюс          734
# 12             Київ          Житомир          131
# 13          Житомир          Донецьк          863
# 14          Житомир        Волгоград         1493
# 15          Кишинів             Київ          467
# 16          Кишинів          Донецьк          812
# 17  Санкт-Петербург         Вітебськ          602
# ...

# %%
cities = open('Cities.txt').read().split('\n')[1:]
cities = {cities[i]:i for i in range(len(cities))}
cities
# Out:
# {'Брест': 0,
#  'Волгоград': 4,
#  'Вороніж': 3,
#  'Вільнюс ': 1,
#  'Вітебськ': 2,
#  'Даугавпілс': 5,
#  'Донецьк': 6,
#  'Житомир': 12,
#  'Казань': 7,
#  'Калінінград': 8,
#  'Каунас': 9,
#  'Кишинів': 11,
#  'Київ': 10,
#  'Москва ': 14,
#  'Мурманськ': 15,
#  'Мінськ': 13,
#  'Нижній Новгород': 16,
#  'Одеса': 18,
#  'Орел': 17,
#  'Рига': 19,
#  'Самара': 20,
#  'Санкт-Петербург': 21,
#  'Сімферополь': 22,
#  'Таллінн': 23,
#  'Уфа': 26,
#  'Харків': 24,
#  'Ярославль': 25}
